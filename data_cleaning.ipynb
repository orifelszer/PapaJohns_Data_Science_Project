# %% [markdown]
# <a href="https://colab.research.google.com/github/Edenshmuel/PapaJohns_Data_Science_Project/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Getting started with data cleaning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Final_Project_PapaJohns/All_years.csv')
# Out:
# <ipython-input-2-44878571b353>:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Final_Project_PapaJohns/All_years.csv')

# %%
df
# Out:
#               Date  Month סוג פריט           תאור סוג מס' פריט  \
# 0       2022-01-01      1      0.0                NaN       67
# 1       2022-01-01      1      0.0                NaN       67
# 2       2022-01-01      1      1.0  פיצות מיוחדות 14'        4
# 3       2022-01-01      1      1.0  פיצות מיוחדות 14'        7
# 4       2022-01-01      1      1.0  פיצות מיוחדות 14'       13
# ...            ...    ...      ...                ...      ...
# 258189  2024-12-31     12       52         מנות נלוות     3117
# 258190  2024-12-31     12       52         מנות נלוות     3210
# 258191  2024-12-31     12       52         מנות נלוות     3210
# 258192  2024-12-31     12       52         מנות נלוות     3210
# 258193  2024-12-31     12       52         מנות נלוות     3210
#
#                                          תאור פריט      הזמנה  כמות    סכום  \
# 0                                              NaN    14328.0     1    4.95
# 1                                              NaN    14354.0     2    9.90
# 2                                   ביאנקה 14'  []    14321.0     1   85.90
# 3                                  טוסקנית  14' []    14304.0     1   85.90
# 4                                  המומלצת  14' []    14358.0     1   89.90
# ...                                            ...        ...   ...     ...
# 258189                               שובר 50 שח DV  7669633.0     5  125.00
# 258190  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669582.0     1    0.00
# 258191  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669585.0     1   19.90
# 258192  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669605.0     1   19.90
# 258193  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669633.0     3  384.00
#
#         הנחה לפריט  אחרי הנחה  Is_original
# 0              0.0       4.95            1
# 1              0.0       9.90            1
# 2              0.0      85.90            1
# 3              0.0      85.90            1
# 4              0.0      89.90            1
# ...            ...        ...          ...
# 258189         0.0     125.00            1
# 258190         0.0       0.00            1
# 258191         0.0      19.90            1
# 258192         0.0      19.90            1
# 258193         0.0     384.00            1
#
# [258194 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258194 entries, 0 to 258193
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Date         255734 non-null  object
#  1   Month        258194 non-null  int64
#  2   סוג פריט     256298 non-null  object
#  3   תאור סוג     239152 non-null  object
#  4   מס' פריט     258194 non-null  object
#  5   תאור פריט    257188 non-null  object
#  6   הזמנה        256298 non-null  float64
#  7   כמות         258194 non-null  int64
#  8   סכום         256978 non-null  float64
#  9   הנחה לפריט   258194 non-null  float64
#  10  אחרי הנחה    257946 non-null  float64
#  11  Is_original  258194 non-null  int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 23.6+ MB

# %% [markdown]
# ## Deleting missing values

# %%
df.dropna(inplace=True)

# %%
df = df[df["כמות"] >= 0]

# %% [markdown]
# ## Convert Date to date format

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# Out:
# <ipython-input-7-4ac1f8d99197>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
weekday_map = {
    0: 2,
    1: 3,
    2: 4,
    3: 5,
    4: 6,
    5: 7,
    6: 1}

# %%
df['Year'] = df['Date'].dt.year
df['Day'] = df['Date'].dt.day
df['Weekday'] = df['Date'].dt.dayofweek  # 0=Monday, 6=Sunday

df['Is_Weekend'] = df['Weekday'].isin([4, 5]).astype(int)
df['Day_Name'] = df['Weekday'].map(weekday_map)
# Out:
# <ipython-input-9-b9d4f4d00aa4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Date'].dt.year
# <ipython-input-9-b9d4f4d00aa4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day'] = df['Date'].dt.day
# <ipython-input-9-b9d4f4d00aa4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weekday'] = df['Date'].dt.dayofweek  # 0=Monday, 6=Sunday
# <ipython-input-9-b9d4f4d00aa4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Is_Weekend'] = df['Weekday'].isin([4, 5]).astype(int)
# <ipython-input-9-b9d4f4d00aa4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day_Name'] = df['Weekday'].map(weekday_map)

# %%
df.tail(3)
# Out:
#              Date  Month סוג פריט    תאור סוג מס' פריט  \
# 258191 2024-12-31     12       52  מנות נלוות     3210
# 258192 2024-12-31     12       52  מנות נלוות     3210
# 258193 2024-12-31     12       52  מנות נלוות     3210
#
#                                          תאור פריט      הזמנה  כמות   סכום  \
# 258191  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669585.0     1   19.9
# 258192  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669605.0     1   19.9
# 258193  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669633.0     3  384.0
#
#         הנחה לפריט  אחרי הנחה  Is_original  Year  Day  Weekday  Is_Weekend  \
# 258191         0.0       19.9            1  2024   31        1           0
# 258192         0.0       19.9            1  2024   31        1           0
# 258193         0.0      384.0            1  2024   31        1           0
#
#         Day_Name
# 258191         3
# 258192         3
# 258193         3

# %%
columns_order = [
    'Date',
    'Year',
    'Month',
    'Day',
    'Day_Name',
    'Is_Weekend',
    'תאור פריט',
    'הזמנה',
    'כמות',
    'סכום',]

df_all_years = df[columns_order].copy()

# %%
df_all_years.tail(3)
# Out:
#              Date  Year  Month  Day  Day_Name  Is_Weekend  \
# 258191 2024-12-31  2024     12   31         3           0
# 258192 2024-12-31  2024     12   31         3           0
# 258193 2024-12-31  2024     12   31         3           0
#
#                                          תאור פריט      הזמנה  כמות   סכום
# 258191  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669585.0     1   19.9
# 258192  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669605.0     1   19.9
# 258193  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669633.0     3  384.0

# %% [markdown]
# ## Daily summary of orders

# %%
daily_summary = df_all_years.groupby('Date').agg({
    'כמות': 'sum',
    'סכום': 'sum',
    'הזמנה': pd.Series.nunique,
    'Is_Weekend': 'first',
}).reset_index()

# שינוי שמות עמודות לנוחות
daily_summary.rename(columns={
    'כמות': 'Total_Quantity',
    'סכום': 'Total_Amount',
    'הזמנה': 'Unique_Orders'}, inplace=True)

daily_summary.sample(3)
# Out:
#           Date  Total_Quantity  Total_Amount  Unique_Orders  Is_Weekend
# 564 2024-10-02             486       8615.70            110           0
# 571 2024-10-09             502       8687.95             93           0
# 223 2023-05-15             370       7874.90             86           0

# %%
df_all_years
# Out:
#              Date  Year  Month  Day  Day_Name  Is_Weekend  \
# 2      2022-01-01  2022      1    1         7           1
# 3      2022-01-01  2022      1    1         7           1
# 4      2022-01-01  2022      1    1         7           1
# 5      2022-01-01  2022      1    1         7           1
# 6      2022-01-01  2022      1    1         7           1
# ...           ...   ...    ...  ...       ...         ...
# 258189 2024-12-31  2024     12   31         3           0
# 258190 2024-12-31  2024     12   31         3           0
# 258191 2024-12-31  2024     12   31         3           0
# 258192 2024-12-31  2024     12   31         3           0
# 258193 2024-12-31  2024     12   31         3           0
#
#                                          תאור פריט      הזמנה  כמות   סכום
# 2                                   ביאנקה 14'  []    14321.0     1   85.9
# 3                                  טוסקנית  14' []    14304.0     1   85.9
# 4                                  המומלצת  14' []    14358.0     1   89.9
# 5                            טוסקנית בצק דק 14' []    14323.0     1   85.9
# 6                            טוסקנית בצק דק 14' []    14355.0     1   85.9
# ...                                            ...        ...   ...    ...
# 258189                               שובר 50 שח DV  7669633.0     5  125.0
# 258190  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669582.0     1    0.0
# 258191  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669585.0     1   19.9
# 258192  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669605.0     1   19.9
# 258193  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669633.0     3  384.0
#
# [238596 rows x 10 columns]

# %%
df_all_years["תאור פריט"].unique()
# Out:
# array(["ביאנקה 14'  []", "טוסקנית  14' []", "המומלצת  14' []",
#        "טוסקנית בצק דק 14' []", "היוונית דקה 14' []", "פאפא מיקס  14' []",
#        "פאפא מיקס דקה 14' []", "עקיצת הדבורה דקה 14' []",
#        "סופר מרגריטה  דקה 14' []", "פיצה ורסיה צמחונית 14' []",
#        "טוסקנית 8' []", "היוונית 8' []", "האיטלקית החריפה 8' []",
#        'אצבעות גבינה', "צ'יזי רול", 'נגיסי תירס', 'ספייסי רולס',
#        'פפיוני שום פרמזן', 'בלונדי בריבוע', 'עוגת ריקוטה', 'קינוח חגיגי',
#        'קוקה קולה 1.5 ליטר', 'קולה זירו 1.5 ליטר', 'דיאט קולה 1.5 ליטר',
#        'פיוז טי אפרסק 1.5 ליטר', 'ספרייט זירו 1.5 ליטר',
#        'ספרייט 1.5 ליטר', "פיוז טי אפרסק 500 מ'ל",
#        "מים מינרלים נביעות 500 מ'ל", 'פחית קוקה קולה', 'פחית קולה זירו',
#        'פחית ספרייט זירו', 'רוטב פיצה קטן', 'רוטב ברביקיו קטן',
#        "רוטב צ'ילי מתוק קטן", 'רוטב שום קטן', 'מארז רטבים',
#        'תבלין איטלקי קטן', 'רוטב שום פרמזן קטן', 'אננס', 'פטריות', 'תירס',
#        'זיתים ירוקים', 'בצל לבן', 'פלפל ירוק', 'בולגרית', 'עגבניות',
#        'זיתי קלמטה', 'תערובת 2 גבינות', 'בצל סגול', "פפרוצ'יני",
#        'חלפיניו', 'תוספת גבינה', 'פפרוני טבעוני', 'תבלין איטלקי',
#        'ארטישוק', 'אנשובי', 'בלי בצל לבן', 'בלי זיתים שחורים',
#        "בלי פפרוצ'יני", 'בלי בולגרית', 'בלי גבינת מוצרלה', 'בלי ארטישוק',
#        "קלאסית 14' ושתייה", '3 מרגריטות קלאסיות', 'פיצה אישית',
#        "2 פיצות 14' + 2 תוספות", '2 פיצות משפחתיות',
#        "מבצע פיצה קלאסית 14' ב64.9 ש'ח", "מבצע ב 19 ש''ח", 'פאפא דיל',
#        '4 פיצות אישיות', 'ארוחת שחיתות', "קלאסית 14' []", "קלאסית 8' []",
#        "קלאסית דקה 14' []", "קלאסית 16' []", "קלאסית דקה 16' []",
#        "הצמחונית 16' []", "טוסקנית  16' []", "היוונית 16' []",
#        "היוונית דקה 16' []", "פאפא מיקס דקה 16' []", '2 מרגריטות קלאסיות',
#        'שוקולד קראנץ רול', "קלאסית 14' + שתייה", '3 רטבים לבחירה',
#        'פיצה אישי 8', 'קלאסית איטסיין [] במקום', 'קלאסית איטסיין []',
#        'היוונית איטסיין []', "טבעונית 14' []", "צ'יזי רול טבעוני",
#        "טבעונית 8' []", 'קלאסית טבעונית איטסיין []',
#        "פיצה ללא גלוטן 14 ' []", 'רוטב באפלו קטן', 'רוטב פיצה מארז',
#        'רוטב ברביקיו מארז', 'רוטב באפלו מארז', 'רוטב שום פאפא מארז',
#        "היוונית 14' []", 'קלסית 14', "סופר מרגריטה  14' []",
#        "המומלצת של פאפא 8' []", 'טבעות בצל', "שוקולד קראנץ' רול",
#        'מים מינרליים נביעות 1.5 ליטר', 'פריגת ענבים 1.5 ליטר',
#        "פריגת ענבים 500 מ'ל", 'פחית פאנטה', 'סודה 250', 'זיתים שחורים',
#        'תערובת 3 גבינות', 'טונה', 'בלי רוטב פיצה',
#        "2 פיצות 14' + 2תוספות +שתיה 1.5", "מרגריטה 8' []",
#        "קלאסית 16'  []", "קלאסית דקה 16'  []", 'שתייה קטנה',
#        'טוסקנית 6 גבינות איטסיין []', 'אצבעות גבינה טבעוניות',
#        "טבעונית 16' []", "קריביאן טבעוני 14' []", 'רוטב פיצה בסיס',
#        "ביאנקה בצק דק 14'  []", "טוליפ דקה 14' []", "טוליפ 8' []",
#        "הצמחונית 8' []", "ביאנקה 8' []", "פאפא מיקס 8' []",
#        "עקיצת הדבורה  8' []", "סופר מרגריטה  8' []", 'גלידה קטנה',
#        'פחית דיאט קולה', 'צאנקי מאנקי  משפחתי', 'קרם עוגיות אישי',
#        'בלי פטריות', 'בלי גבינה', 'בלי עגבניות', 'מבצע פיצה וקינוח',
#        "טוליפ 16' []", "טוליפ דקה 16' []", "ביאנקה דקה 16' []",
#        "סופר פאפא טבעוני 8' []", "רוטב צ'ילי מתוק מארז", "טוליפ 14' []",
#        "הצמחונית 14' []", 'פאנטה 1.5 ליטר', 'פחית ספרייט',
#        "דולצה דה לצ'ה  אישי", 'צאנקי מאנקי  אישי', 'שוקולד בראוניס אישי',
#        'נקניק טבעוני', 'כדורי בשר טבעוניים', 'בלי בצל סגול', 'בלי תירס',
#        'בלי פלפל ירוק', 'בלי נגיעות שמנת', 'מבצע ערב סרט משפחתי',
#        "הצמחונית דקה 16' []", "פאפא מיקס  16' []", "עקיצת הדבורה  16' []",
#        "טונה דה לקס  דקה 16' []", 'פאפא מיקס איטסיין []',
#        "סופר פאפא טבעוני 16' []", "האיטלקית החריפה בצק דק 14' []",
#        "עקיצת הדבורה  14' []", 'סופר מרגריטה ללא גלוטן',
#        "פריגת תפוזים 500 מ''ל", 'שוקולד בראוניס משפחתי',
#        'בצק עוגיות  אישי', "ביאנקה 16' []", '2 פיצות + מנת צד',
#        'הצמחונית איטסיין []', 'ביאנקה איטסיין []',
#        'פפרוני  ספיישל כשר איטסיין []', "היוונית ללא גלוטן 14 ' []",
#        "טונה דה לקס  14' []", 'פאפא מיקס ללא גלוטן',
#        "נקניקיות צ'וריסוס טבעוניות", 'בלי פפרוני', 'בלי נקניק איטלקי',
#        'בלי טונה', 'בלי כדורי בשר', 'בלי כדורי בשר טבעוניים',
#        'מבצע 10 קלאסיות', "המומלצת דקה 16' []", "טוסקנית דקה 16' []",
#        "עקיצת הדבורה  דקה 16' []", 'פיצה מיוחדת בחצי מחיר בקנייה משפחתית',
#        'טוליפ איטסיין []', 'סופר פאפא כשר איטסיין []',
#        "קריביאן טבעוני 8' []", "טונה דה לקס  8' []", 'גלידה גדולה',
#        "דולצה דה לצ'ה  משפחתי", '6 פיצות מרגריטה', "קלאסית 14'  2 []",
#        "קלאסית 14' 3 []", "קלאסית 14' 4 []", "קלאסית 14' 5 []",
#        "קלאסית 14' 6 []", "מבצע 4 פיצות 14'", "סופר מרגריטה  דקה 16' []",
#        "טוליפ ללא גלוטן 14 ' []", 'רוטב חריף', 'בלי 6 גבינות איטלקיות',
#        "מנת צד ב-5ש''ח  בקניית משפחתית", 'עוף ברבקיו כשר איטסיין []',
#        'המומלצת של פאפא כשר איטסיין []', 'קלאסית + קינוח + גלידה קטנה',
#        'קריביאן כשר איטסיין  []', "הבשרית טבעוני 8' []", 'גבינה טבעונית',
#        'בלי תערובת תבלינים איטלקיים', "המומלצת של פאפא 16' []",
#        "טבעונית דקה  14' []", "הצמחונית ללא גלוטן 14 ' []",
#        "ללא גלוטן טבעונית  14 ' []", 'מעט רוטב', "טונה דה לקס  16' []",
#        "סופר מרגריטה  16' []", "הצמחונית דקה 14' []", 'בצק עוגיות משפחתי',
#        "טופי קראנ'ץ  משפחתי", "האיטלקית החריפה  14' []",
#        "טונה דה לקס דקה 14' []", 'בלי אננס', "סופר פאפא טבעוני 14' []",
#        "קריביאן טבעוני דקה 16' []", 'קלאסית 14 +2 תוס +מנת צד+קינוח',
#        'קרם עוגיות משפחתי', 'בלי רוטב שום', 'תו ירוק זית',
#        "המומלצת של פאפא בצק דק 14' []", "טבעונית דקה 16' []",
#        'רוטב ציפוטלה קטן', '2 קלאסיות +גלידה 500 + שתייה 1.5 ליטר',
#        "האיטלקית החריפה 16' []", 'קלאסית + 2 תוס + מארז רטבים',
#        'פיצה קלאסית + איטסיין/ללא גלוטן ב 50%', "הבשרית טבעוני 14' []",
#        "סופר פאפא טבעוני דקה 14' []", 'בלי פפרוני טבעוני',
#        "פיצה 8' ת.טבעונית", 'קלאסית + 2 מנות נלוות',
#        "קריביאן טבעוני דקה 14' []", 'בלי נקניק טבעוני',
#        'פיצה אישית ב10שח  יום הפיצה הבינלאומי', 'חבק יורו',
#        'מבצע וליינטיינס', "פיצה לב דקה  14' []",
#        "פיצה 14' [] בצורת לב עבה", 'טונה דה לקס ללא גלוטן',
#        'פפרוני רול טבעוני', "סופר וונדרס טבעוני 14' []",
#        'בלי קורט אורגנו', 'מדבקת וונדרס', "סופר וונדרס צמחוני 14' []",
#        "ללא רוטב צ'יפוטלה דבש", 'ארוחת ילדים', "נגיסי תירס 5 יח'",
#        'הפתעה לבת', 'הפתעה ארוחת ילדים קעקועים / מדבקות',
#        'כרטיס מתנה של BIGI', 'בלי בצל', "טבעות בצל 5 יח'",
#        'קעקועים ארוחת ילדים', "פאפא וונדרס צמחוני 14' []",
#        'בלי גבינה בולגרית', '2 קלאסיות + 2 קינוחים + מארז רטבים',
#        "כדורי פירה 12 יח'", "מוצרלה סטיקס 8 יח'", '5 כדורי פירה',
#        "אצבעות מוצרלה 3 יח'", "קריביאן טבעוני 16' []", 'פפרוני',
#        'קלאסית + מנת צד + שתייה 1.5 ליטר', 'פלפל פפרוציני [שלם]',
#        'בלי נתחי עוף', "הבשרית טבעוני 16' []", 'בלי תערובת 2 גבינות',
#        "פיצה ציטוס 14' []", 'אצבעות גבינה ציטוס', 'משולשי קרטון ציטוס',
#        "פיצה ציטוס 14' + אצבעות גבינה ציטוס + מארז רטבים", 'נוטלה',
#        'האיטלקית החריפה כשר איטסיין []', "פיצה ציטוס 8' []",
#        "פיצה ציטוס 14 דקה' []", "פיצה ציטוס 16 דקה' []",
#        "פיצה ציטוס 14' + קלאסית 14'", "פיצה ציטוס 16 ' []",
#        'עוגת ריקוטה שוקולד', "פיצת גמר הישרדות 14'",
#        "פיצת גמר דקה הישרדות 14'",
#        "פיצת הגמר + קינוח לבחירה[ללא בן&ג'רי] + מארז רטבים",
#        '3 משולשי קרטון לפיצה', 'רוטב שום גדול', "רוטב צ'יפוטלה דבש גדול",
#        'רוטב באפלו גדול', 'רוטב פיצה גדול', 'רוטב שום פרמזן גדול',
#        'כדורגל זוגי', 'מגש כדורגל',
#        "פיצה L קלאסית + 2 פחיות + אצבעות גבינה ב-99 ש'ח", 'מארז 2 פחיות',
#        'מגש מונדיאל', 'כדור פינג פונג', '1 מגש כדורגל',
#        "2 פיצות L קלאסיות + 4 פחיות שתיה ב 139 ש'ח", 'מארז 4 פחיות',
#        "מגנום וניל קלאסיק 63 מ'ל", 'פיצה קלאסית וגלידה קטנה',
#        'רולס פיסטוק', "מגנום וניל שקדים 57 מ'ל", 'רוטב ברביקיו גדול',
#        'מארז 3 רטבים', "צ'יזי טונה 8 כשר' []", "קליק שוקולד בננה 520 מ'ל",
#        "רוטב צ'ילי מתוק גדול", "קליק גלידה 520 מ'ל", 'מים בטעמים',
#        "הוט-דוג שיקגו סטייל 8 כשר' []", "מגנום שוקולד לבן עוגיות 440 מ'ל",
#        'גלידה משפחתית', "סופר וונדרס צמחוני 8' []", 'דקה',
#        'מארז קינוח מובנפיק', "צ'יזי טונה 14 כשר' []",
#        "פפרוני טבעוני ספיישל 8' []", 'רולס נוגט', 'רולס קרמל מלוח',
#        'ללא רוטב', '2 מגשי כדורגל', '2 כדורי פינג פונג',
#        'פיצה משפחתית קלאסית  + קינוח רולס + גלידה קטנה',
#        "הוט-דוג שיקגו סטייל 16 כשר דקה' []",
#        "הוט-דוג שיקגו סטייל 14 דקה' []", 'כדורי בשר', 'פיצה משפחתית 14',
#        'תבלין איטלקי גדול', 'פפרוני רול', 'הקשה של הפיצה',
#        "הוט-דוג שיקגו סטייל 16 כשר' []", '3 פלפלים פפרוציני',
#        'קלאסית + מנת צד + מארז רטבים', 'מוצרלה',
#        "מגנום וניל שוקולד לבן 440 מ'ל", "קלאסית 14' +מנת צד + שתייה 1.5",
#        '2 פיצות משפחתיות + 2 תוספות', "קליק שוקולד לבן עוגיות 520 מ'ל",
#        'בלי גמבה', 'גלידה אישית', 'רוטב חרדל גדול', 'רוטב חרדל קטן',
#        'ללא גבינה', "פפרוני טבעוני ספיישל 14' []",
#        '2 פיצות משפחתיות קלאסיות RL', 'פיצה מיוחדת + מנה נלוות',
#        "מגנום וניל קלאסיק 440 מ'ל",
#        '2 פיצות משפחתיות קלאסיות  + גלידה גדולה',
#        'פיצה משפחתית + מנה נלוות',
#        'משפחתית + נלוות + מארז + HTZ כולל משלוח', 'שתיה גדולה פיצוי',
#        'פיצה משפחתית + תוספות', '2 פיצות משפחתיות בנק מזרחי',
#        "פאפא וונדרס צמחוני  8' []", "פאפא קראסט קלאסי 14' []",
#        'מגש הישרדות + גלויה הישרדות', "בלי צ'ילי כתוש",
#        'האיטלקית החריפה איטסיין []', "הבשרית טבעוני דקה 14' []",
#        'פיצה לב + גלידה גדולה', 'מגש וולנטיין', "פאפא קראסט חריף 14' []",
#        "5 פיצות משפחתיות ב-240 ש'ח", '3 פיצות משפחתיות RL',
#        'גלויה וולנטיין', 'פיצה לב + 2 גלידות קטנות',
#        'פיצה איטסיין + שתיה ב 55', "קליק וניל קרמל 520 מ'ל", 'מנה נלוות',
#        "מגנום גולד 440 מ'ל", "פפרוני טבעוני ספיישל 16' []",
#        'סופר מרגריטה איטסיין []', 'פיצה משפחתית + שתיה גדולה',
#        "סופר פאפא טבעוני דקה 16' []", "פאפא קראסט פפרוני 14' []",
#        'משפחתית + נלוות +שתיה גדולה', '2 משפחתיות + נלוות + קראנץ רול',
#        'פיצה קלאסית + פאפא קראסט', 'קינוח פיצוי', "קריביאן 14' []",
#        "פאפא נאגטס 5 יח'", "הוט פאפאס 5 יח'", "פפרוני טבעוני קראסט' []",
#        'פאפא קראסט קלאסי', "כנפיים ברוטב 8 יח'",
#        "מגנום וניל שקדים 440 מ'ל", 'משפחתית + קינוח רול ST',
#        "צ'יזי טונה 8' []", "ברביקיו סלופי ג'ונס 14 כשר' []",
#        'פאפא קראסט + שתיה גדולה', 'קינדר דליס', 'הטבה במחיר מיוחד',
#        'פיצה טבעונית + נלוות טבעוני', 'שתי משפחתיות קלאסיות',
#        "קלאסית ללא גלוטן פסח 14' []", "יוונית ללא גלוטן פסח 8' []",
#        'משפחתית ומנה נלוות', "אישית ללא גלוטן פסח 8' []",
#        '2 פיצות ללא גלוטן משפחתיות + שתיה 1.5',
#        "צמחונית ללא גלוטן פסח 8' []", "יוונית ללא גלוטן פסח 14' []",
#        'פיצה ללא גלוטן משפחתית + שתיה', "צמחונית ללא גלוטן פסח 14' []",
#        'רוטב פיצה גדול פסח', "טוליפ ללא גלוטן פסח 8' []",
#        "טוליפ ללא גלוטן פסח 14' []", 'מארז 3 פחיות',
#        'פאפא קראסט + מנה נלוות', "ברביקיו סלופי ג'ונס 8 כשר' []",
#        "הבשרית טבעוני דקה 16' []", 'פיצה משפחתית + שתיה 1.5 ל RL',
#        'פיצה אישית + אצבעות גבינה + פחית', 'ללא גבינה טבעונית',
#        'משפחתית + מנה נלווית', 'פיצה משפחתית', "סופר פאפא דקה 14'",
#        "סופר פאפא 14' []", 'פיצה משפחתית + תוספת צמחונית',
#        "פפרוני ספיישל צמחוני דקה [] 16'", "סופר פאפא 8' []",
#        "המומלצת של פאפא צמחוני [] 16'", "פפרוני ספיישל צמחוני []  14'",
#        "ביאנקה ללא גלוטן 14 ' []", "קריביאן צמחוני [] 8'",
#        "הספרדית 14' []", "פפרוני ספיישל צמחוני [] 16'", "האנגלית 14' []",
#        'פיצה מיוחדת של שבועות + פיצה קלאסית משפחתית', "הצרפתית 14' []",
#        "האיטלקית החריפה צמחוני דקה [] 16'", "הספרדית 16' []",
#        "הצרפתית דקה 14' []", "הצרפתית דקה 16' []",
#        '2 משפחתיות קלאסיות ST', "הספרדית דקה 14' []",
#        "קריביאן צמחוני דקה [] 14'", "הספרדית 8' []",
#        'משפחתית + מנה נלוות', "2 יח' עוגיות מדלן שוקולד-צ'יפס",
#        "הספרדית דקה 16' []", "האיטלקית  דקה 16' []",
#        "סופר פאפא דקה 16' []", 'גבינת עיזים', "גבינת מצנג'ו",
#        "פפרוני ספיישל צמחוני דקה [] 14'", 'שום קונפי', "סופר פאפא 16' []",
#        '2 פיצות פיצוי', 'רוטב גדול פיצוי',
#        "המומלצת של פאפא צמחוני [] 14'", "סופר פאפא צמחוני [] 8'",
#        'גבינת קשקבל', "הצרפתית  16' []", 'נקניק איטלקי',
#        'משפחתית קלאסית + 2 פחיות', "המומלצת של פאפא צמחוני דקה [] 16'",
#        "סופר פאפא צמחוני דקה [] 16'", "סופר פאפא צמחוני [] 14'",
#        "פפרוני ספיישל 14' []",
#        'משפחתית קלאסית + מנת אמריקה + 2 פחיות שתיה',
#        'נקניקיית קצבים מנתחי בקר איכותיים', "צ'יפס",
#        'מנת אמריקה + פחית שתיה', 'נקניקייה טבעונית',
#        "פפרוני ספיישל צמחוני [] 8'", "הוט-דוג שיקגו סטייל 16 דקה' []",
#        'הטבת יום הולדת', 'סופר פאפא איטסיין []',
#        "הוט-דוג שיקגו סטייל 14' []", 'משולשי גאווה',
#        'משפחתית + נלוות + שתיה  1.5', '2 משפחתיות + מנה נלוות',
#        "צ'יזי טונה 14' []", 'הפצה מנת אמריקה',
#        "המומלצת של פאפא צמחוני [] 8'",
#        "משפחתית קלאסית + אצבעות גבינה + שתיה 1.5 ל'", 'רוטבים',
#        "קריביאן צמחוני [] 16'", 'פיצה קלאסית',
#        "המומלצת של פאפא צמחוני דקה [] 14'",
#        'משפחתית + נלוות + רול שוקולד', "סופר פאפא צמחוני [] 16'",
#        "קריביאן בצק דק 16' []", "פפרוני ספיישל בצק דק 14' []",
#        "קריביאן בצק דק 14' []", "קריביאן 8' []", 'גרליק בייטס 24 יחידות',
#        'רולס בייגלה שמנת ועוגיות', 'רולס פירות יער שמנת',
#        'רולס פצפוצי רושה ופיסטוק שמנת', 'ספרון מדבקות לילדים - תרומה',
#        'פיצה משפחתית + רול חנוכה', '2 פיצות משפחתיות + רול חנוכה',
#        'פיצה משפחתית קלאסית + ספרון מדבקות לתרומה', 'עם צילי חריף',
#        'קלפי ליגת האלופות', 'עם רוטב בייגלה', 'עם רוטב פירות יער',
#        'עם רוטב פיסטוק', 'עם אורגנו', 'עם תבלין איטלקי',
#        '2 פיצות L קלאסיות + קינוח / נלוות  + שתיה גדולה',
#        'רולס מרשמלו שמנת ועוגיות', "הבשרית 16' []", 'עם רוטב מרשמלו',
#        "פפרוני ספיישל 16' []", 'פפרוני ספיישל איטסיין []',
#        'תערובת 5 גבינות', "הוט פאפא קלאסי 2 יח'", 'בלי תערובת גבינות',
#        "האיטלקית החריפה צמחוני [] 16'", 'קרם בייגלה מלוח',
#        'קרם שוקולד נוגט', 'מנה נלוות + מארז פיצוי',
#        'פיצה L קלאסית + תוספת צמחונית + משלוח PO',
#        "קלמטה 6 גבינות  16' []", "הבלקנית 14' []",
#        "קלמטה 6 גבינות  16 דקה ' []",
#        'פיצה מיוחדת ממהדורת חורף + פיצה קלאסית',
#        "צ'יזי פסטו [צמחונית] 14 דקה ' []", "קלמטה 6 גבינות  14' []",
#        "קלמטה 6 גבינות  14 דקה ' []",
#        'פיצה מיוחדת ממהדורת חורף + 2 פחיות או מנת נלוות',
#        'הבלקנית איטסיין []', "צ'יזי פסטו [צמחונית] 14' []",
#        "הבלקנית 16' []", "קלמטה 6 גבינות  8' []", 'שובר 100 שח DV',
#        '2 פיצות קלאסיות + 2 תוספות + שתיה 1.5', 'קרם פיסטוק רושה',
#        'פיצה משפחתית + תוספת צמחונית + מנה נלווית HOT',
#        "הבלקנית 14 דקה ' []", '2 פיצות משפחתיות  + קינוח',
#        'פיצה קלאסית + 2 תוספות + קינוח',
#        '2 פיצות משפחתיות + קינוח / שתיה גדולה', 'שינוי למשלוח',
#        "צ'יזי פסטו [צמחונית] 8' []", 'קלמטה 6 גבינות  איטסיין []',
#        'פיצה משפחתית קלאסית + תוספת צמחונית + דמי משלוח TD',
#        'פיצה משפחתית + אצבעות גבינה + משלוח WL',
#        'פיצה משפחתית קלאסית + נלוות + משלוח WG',
#        'פיצה משפחתית קלאסית + גלידה גדולה', "הבלקנית 16 דקה' []",
#        'פיצה קלאסית + תוספת צמחונית בנק לאומי',
#        'פיצה קלאסית + קינוח רולס +  גלידה גדולה',
#        'משפחתית קלאסית + תוספת צמחונית + משלוח 911',
#        "צ'יזי פסטו איטסיין []", 'פיצה משפחתית קלאסית + תוספת צמחונית MAX',
#        'פיצה קלאסית + תוספת צמחונית באיסוף עצמי SG',
#        'פיצה 16 + תוספת פיצוי', "הבלקנית 8' []",
#        "צ'יזי פסטו [צמחונית] 16' []", "מגנום פופוקורן וקרמל 440 מ'ל",
#        'פיצה L קלאסית + תוספת צמחונית + שתיה 1.5 ליטר HOT',
#        "מגנום מנגו וקוקוס 440 מ'ל", 'יום הבחירות - פיצה L + תוספת באיסוף',
#        "ויגן פסטו 8' []", "קריביאן צמחוני [] 14'", "קלאסית 14' + 2תוס []",
#        'פיצה משפחתית + גרליק בייטס + שתיה גדולה', 'בלי זיתים ירוקים',
#        'פיצה L קלאסית  + גרליק בייטס',
#        'פיצה קלאסית + תוספת צמחוניות + שוקולד קראנץ רול', 'כף זהב מגנום',
#        'פיצה L קלאסית + פיינט מגנום',
#        '2 פיצות + קינוח + נלוות + 2 פחיות שתיה',
#        'פיצה משפחתית קלאסית באיסוף בנק מזרחי',
#        '3 פיצות קלאסיות + 3 תוספות צמחוניות',
#        '2 משפחתיות קלאסיות + מנה נלווית', 'משפחתית + תוספת צמחונית',
#        'פיצה L קלאסית + מנה נלוות + קינוח', 'רול ממרח עגבניות וזיתים',
#        'אצבעות גבינה ממרח קלמטה', "צ'אנקי קוקי",
#        'עם אגוזי לוז פיסטוק מקופלת ואוראו', 'מנה נלוות BO',
#        "האיטלקית החריפה צמחוני [] 8'", "סופר פאפא צמחוני דקה [] 14'",
#        "הוט-דוג שיקגו סטייל 14 כשר דקה' []",
#        'אצבעות גבינה ממרח קלמטה טבעוניות', 'מונסטר אולטרה',
#        "קריביאן צמחוני דקה [] 16'", "טוסקנית ללא גלוטן 14 ' []",
#        '3 פיצות ללא גלוטן משפחתיות', 'אצבעות גבינה פסח',
#        'רוטב שום לבן קטן פסח', 'רוטב שום לבן גדול פסח', 'שקית לקוח',
#        '2 פיצות משפחתיות + מנה נלוות', 'בצק M',
#        "האיטלקית החריפה צמחוני [] 14'",
#        'פיצה משפחתית קלאסית + תוספת צמחונית באיסוף HOT',
#        "הוט-דוג שיקגו סטייל 14 כשר' []", 'מונסטר מנגו לוקו',
#        "ויגן פסטו 14' []", "2 משפחתיות קלאסיות + שתיה 1.5 ל' ב-135",
#        '10 נאגטס עוף + ציפס וופל', 'מונסטר אנרגי',
#        'פיצה משפחתית + מנה נלוות MAMI',
#        'פיצה L קלאסית + תוספת צמחונית + מנה נלווית', 'רוטב ראנץ קטן',
#        'חגיגות 30 קינוח', '3 משפחתיות קלאסיות + 3 תוספות',
#        'פיצה משפחתית + מנה נלווית + שתיה גדולה',
#        '2 פיצות משפחתיות + נלוות + קינוח + 2 פחיות',
#        "פיצה קלאסית [L] + תוספת צמחונית + שתיה 1.5 ל'",
#        '2 פיצות משפחתיות + 2 תוספות + שתיה 1.5 ליטר', 'שתייה גדולה',
#        "קלאסית 12' []", 'קורנפלקס דליס', 'אצבעות פסטו קרונפלקס',
#        'המומלצת של פאפא איטסיין []', 'פיצה קלאסית באיסוף עצמי SG',
#        "קרונפלקס פטריות 14' []", 'פיצה קורנפלקס + 2 פחיות',
#        'פיצה משפחתית קלאסית + קינוח + נלוות + מארז רטבים',
#        "קראנץ פפרוני טבעוני 14' []", 'רוטב ראנץ גדול',
#        'פיצה קורנפלקס + פיצה משפחתית קלאסית + 2 פחיות',
#        'פיצה קורנפלקס + 2 פחיות + מנה נלווית או קינוח',
#        'פיצה L קלאסית + תוספת + מנה נלווית + 2 פחיות',
#        'פיצה משפחתית + מנה נלוות / קינוח + 2 פחיות', 'שובר 50 שח DV',
#        "פיצה לב זוגית + צ'אנקי קוקי", '8 טבעות גאודה מצופות',
#        'קינוח / מנה נלוות מהדורת קרונפלקס +  פחית שתיה',
#        'פיצה לב + שוקלד קראנץ רול', '2 פחיות מונסטר בקניה מעל מינימום',
#        '2 משפחתיות קלאסיות WL', 'פיצה M זוגית + תוספת צמחונית',
#        'פיצה L קלאסית + מנה נלווית + 2 פחיות מונסטר',
#        'פיצה L קלאסית + פחית מונסטר לבחירה',
#        'פיצה קלאסית + 3  תוספות חינם', 'וופל קריספי ציפס',
#        'גרביים ממותגות', 'משפחתית קלאסית ומקבלים מנה נלוות במתנה',
#        '2 פיצות זוגיות + 2 פחיות', 'חטיפי פיסס בצק עוגיות  משפחתי',
#        'מנה נלוות + שתיה', 'גלידה', '8 פיצות קלאסיות',
#        'פיצה זוגית קלאסית ב MAMI 40', 'פיצה קלאסית + נלוות/קינוח',
#        'ללא משולשים', 'פיצות מיוחדות', 'תוספת לכל המגש', 'תוספת לחצי מגש',
#        'מנה נלוות + קינוח', "קרונפלקס פפרוני 14' []",
#        "פיצה קלאסית [L] + שתיה 1.5 ל'", 'פיצה משפחתית PJ', 'בצק S',
#        'שוקולד קראנץ רול מתנה', "פסטו ארטישוק 14' []", "לחמעג'ון 8' []",
#        "פסטו ארטישוק 8' []", "פריקסה 8' []", "פריקסה 16' []",
#        "פריקסה 14' []", "לחמעג'ון טבעוני 8' []", "לחמעג'ון 14' []",
#        "פסטו ארטישוק 16' []", "לחמעג'ון טבעוני 14' []",
#        '2 פיצות משפחתיות ב-89 שח',
#        '2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר',
#        'פיצה משפחתית + תוספת + 2 פחיות CL', "לחמעג'ון טבעוני 16' []",
#        'גרביים בלי מידה', 'פיצה משפחתית [L] + מנה נלוות',
#        '2 פיצות משפחתיות [L] + קינוח', 'פאפא קראסט  + שתייה',
#        'פיצה אישית + פחית', '4 פיצות קלאסיות',
#        'פיצה L קלאסית + פיינט גלידה B&J', 'פיצת שף משפחתית + פיצה קלאסית',
#        "שובר 100 ש'ח 1824", 'פיצה משפחתית קלאסית + רולס חנוכה',
#        'פיצה איטסיין / ללא גלוטן  + פיצה קלאסית + שתייה',
#        'פאפא קראסט חריף', 'ניו - יורק סופר  משפחתי', "הבשרית 14' []",
#        '3 פיצות משפחתיות קלאסיות'], dtype=object)

# %%
main_dishes_keywords = ['ביאנקה', 'טוסקנית', 'היוונית', 'הצמחונית', 'קריביאן', 'פפרוני ספיישל', 'טוליפ', 'סופר פאפא' , 'המומלצת', 'הבשרית', 'קלאסית', 'מרגריטה', 'האיטלקית', 'ספייסי רול', 'מוצרלה סטיקס', 'הקשה של הפיצה',
                        'פפיוני שום פרמזן', 'טבעות', 'לחמעג\'ון', 'צ\'יזי רול', 'נאגטס', 'נגיסי', 'פיצה', 'פיצות', 'משפחתית', 'משפחתי', 'אישית', 'איטסיין', 'פריקסה', 'סופר פאפא', 'קראסט', 'כדורי פירה', 'הוט-דוג', 'כדורי בשר',
                        'ארוחה', 'ארוחות', 'פאפאדיאס', 'קלאסי', 'הבלקנית', 'הספרדית', 'הצרפתית', 'סלופי', 'מנה', 'ציפס', '8', '14', '16', 'בייטס', 'עקיצת הדבורה']
Desserts_keywords = ['קראנצ', 'פיסטוק', 'בייגלה', 'קרמל', 'שוקולד', 'בלונדי', 'ריקוטה', 'עוגיות', 'גלידה', 'גלידות', 'מגנום', 'קינוח', 'וניל', 'דולצה', 'צ\'אנקי', 'בראוניס', 'טופי', 'אוראו', 'מקופלת',
                     'אגוזי', 'קליק', 'קרם', 'נוגט', 'פירות', 'שמנת', 'קינדר', 'רול']
Toppings_keywords = ['זית', 'תירס', 'אננס', 'בצל', 'פטריות', 'עגבניות', 'גמבה', 'פלפל', 'חלפיניו', 'גבינה', 'גבינות', 'תוספת', 'ארטישוק', 'בולגרית', 'טונה', 'אנשובי', 'פפרוני', 'מוצרלה', 'פפרוצ\'יני',
                     'קלמטה', 'עיזים', 'חצי', 'תוספות']
sauces_keywords = ["רוטב", "מארז רטבים", "תבלין", 'אורגנו']
drinks_keywords = ["קולה", "מים", "ספרייט", "פחית", "זירו", "מונסטר", "פריגת", "פיוז טי", "משקה", "שתייה", 'פאנטה', 'שתיה']

# %%
def categorize_item(description):
    if pd.isna(description):
        return "אחר"

    desc = description.lower()

    if any(word in desc for word in main_dishes_keywords):
        return "מנה עיקרית"
    elif any(word in desc for word in Desserts_keywords):
        return "קינוח"
    elif any(word in desc for word in Toppings_keywords):
        return "תוספת"
    elif any(word in desc for word in sauces_keywords):
        return "רוטב"
    elif any(word in desc for word in drinks_keywords):
        return "שתייה"
    else:
        return "אחר"

# %%
import re

def split_description(text):
    if pd.isna(text):
        return []
    text = text.lower()
    return re.split(r'\+|/|&| ו ', text)  # מחלק לפי תווים שמחברים פריטים

# %%
def categorize_components(text):
    components = split_description(text)
    categories = set()

    for comp in components:
        cat = categorize_item(comp.strip())
        if cat != "אחר":
            categories.add(cat)

    return list(categories) if categories else ["אחר"]

# %%
df_all_years["קטגוריות בתיאור"] = df_all_years["תאור פריט"].apply(categorize_components)

# %%
df_exploded = df_all_years.explode("קטגוריות בתיאור").copy()
df_exploded.rename(columns={"קטגוריות בתיאור": "קטגוריה"}, inplace=True)

# %%
df_exploded["Date"] = pd.to_datetime(df_exploded["Date"], errors="coerce")
df_exploded["Month"] = df_exploded["Date"].dt.to_period("M")

# סכימת ביקוש לפי קטגוריה וחודש
monthly_demand_by_category = (
    df_exploded.groupby(["Month", "קטגוריה"])["כמות"]
    .sum()
    .unstack()
    .fillna(0))

# %%
df_all_years
# Out:
#              Date  Year  Month  Day  Day_Name  Is_Weekend  \
# 2      2022-01-01  2022      1    1         7           1
# 3      2022-01-01  2022      1    1         7           1
# 4      2022-01-01  2022      1    1         7           1
# 5      2022-01-01  2022      1    1         7           1
# 6      2022-01-01  2022      1    1         7           1
# ...           ...   ...    ...  ...       ...         ...
# 258189 2024-12-31  2024     12   31         3           0
# 258190 2024-12-31  2024     12   31         3           0
# 258191 2024-12-31  2024     12   31         3           0
# 258192 2024-12-31  2024     12   31         3           0
# 258193 2024-12-31  2024     12   31         3           0
#
#                                          תאור פריט      הזמנה  כמות   סכום  \
# 2                                   ביאנקה 14'  []    14321.0     1   85.9
# 3                                  טוסקנית  14' []    14304.0     1   85.9
# 4                                  המומלצת  14' []    14358.0     1   89.9
# 5                            טוסקנית בצק דק 14' []    14323.0     1   85.9
# 6                            טוסקנית בצק דק 14' []    14355.0     1   85.9
# ...                                            ...        ...   ...    ...
# 258189                               שובר 50 שח DV  7669633.0     5  125.0
# 258190  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669582.0     1    0.0
# 258191  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669585.0     1   19.9
# 258192  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669605.0     1   19.9
# 258193  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669633.0     3  384.0
#
#             קטגוריות בתיאור
# 2              [מנה עיקרית]
# 3              [מנה עיקרית]
# 4              [מנה עיקרית]
# 5              [מנה עיקרית]
# 6              [מנה עיקרית]
# ...                     ...
# 258189                [אחר]
# 258190  [תוספת, מנה עיקרית]
# 258191  [תוספת, מנה עיקרית]
# 258192  [תוספת, מנה עיקרית]
# 258193  [תוספת, מנה עיקרית]
#
# [238596 rows x 11 columns]

# %%
def extract_quantity_by_keywords(text):
    if pd.isna(text):
        return {}

    text = text.lower()
    result = {}

    # מיפוי קטגוריות לרשימות מילות מפתח
    category_keywords = {
        "מנה עיקרית": main_dishes_keywords,
        "תוספת": Toppings_keywords,
        "שתייה": drinks_keywords,
        "רוטב": sauces_keywords,
        "קינוח": Desserts_keywords
    }

    for category, keywords in category_keywords.items():
        for kw in keywords:
            # מחפש ביטוי כמו: "2 פיצות", "3 בצל", "1 פיוז טי"
            pattern = rf"(\d+)\s*{re.escape(kw)}"
            matches = re.findall(pattern, text)
            for m in matches:
                num = int(m)
                result[category] = result.get(category, 0) + num

    return result

# %%
df_all_years["כמות בפועל"] = df_all_years["תאור פריט"].apply(extract_quantity_by_keywords)

# %%
df_all_years
# Out:
#              Date  Year  Month  Day  Day_Name  Is_Weekend  \
# 2      2022-01-01  2022      1    1         7           1
# 3      2022-01-01  2022      1    1         7           1
# 4      2022-01-01  2022      1    1         7           1
# 5      2022-01-01  2022      1    1         7           1
# 6      2022-01-01  2022      1    1         7           1
# ...           ...   ...    ...  ...       ...         ...
# 258189 2024-12-31  2024     12   31         3           0
# 258190 2024-12-31  2024     12   31         3           0
# 258191 2024-12-31  2024     12   31         3           0
# 258192 2024-12-31  2024     12   31         3           0
# 258193 2024-12-31  2024     12   31         3           0
#
#                                          תאור פריט      הזמנה  כמות   סכום  \
# 2                                   ביאנקה 14'  []    14321.0     1   85.9
# 3                                  טוסקנית  14' []    14304.0     1   85.9
# 4                                  המומלצת  14' []    14358.0     1   89.9
# 5                            טוסקנית בצק דק 14' []    14323.0     1   85.9
# 6                            טוסקנית בצק דק 14' []    14355.0     1   85.9
# ...                                            ...        ...   ...    ...
# 258189                               שובר 50 שח DV  7669633.0     5  125.0
# 258190  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669582.0     1    0.0
# 258191  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669585.0     1   19.9
# 258192  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669605.0     1   19.9
# 258193  2 משפחתיות קלאסיות + 2 תוספות צמחוניות חבר  7669633.0     3  384.0
#
#             קטגוריות בתיאור                     כמות בפועל
# 2              [מנה עיקרית]                             {}
# 3              [מנה עיקרית]                             {}
# 4              [מנה עיקרית]                             {}
# 5              [מנה עיקרית]                             {}
# 6              [מנה עיקרית]                             {}
# ...                     ...                            ...
# 258189                [אחר]                             {}
# 258190  [תוספת, מנה עיקרית]  {'מנה עיקרית': 2, 'תוספת': 2}
# 258191  [תוספת, מנה עיקרית]  {'מנה עיקרית': 2, 'תוספת': 2}
# 258192  [תוספת, מנה עיקרית]  {'מנה עיקרית': 2, 'תוספת': 2}
# 258193  [תוספת, מנה עיקרית]  {'מנה עיקרית': 2, 'תוספת': 2}
#
# [238596 rows x 12 columns]

# %%
def find_phrase_in_text(text, keywords):
    for kw in keywords:
        if kw in text:
            # חפש מיקום המילה בטקסט
            pattern = rf"(\d+\s*[\w\s\-'״״\"׳]*{re.escape(kw)}[\w\s\-'״״\"׳]*)"
            match = re.search(pattern, text)
            if match:
                return match.group(1).strip()
    return None

# %%
rows = []

for _, row in df_all_years.iterrows():
    base_data = row.drop(["כמות בפועל", "תאור פריט", "כמות"]).to_dict()
    original_text = row["תאור פריט"].lower() if pd.notna(row["תאור פריט"]) else ""
    quantity_dict = row["כמות בפועל"]
    default_qty = row["כמות"]

    if quantity_dict:
        for category, qty in quantity_dict.items():
            new_row = base_data.copy()

            # שולף קטע רלוונטי מהתיאור לפי קטגוריה
            if category == "מנה עיקרית":
                phrase = find_phrase_in_text(original_text, main_dishes_keywords)
            elif category == "תוספת":
                phrase = find_phrase_in_text(original_text, Toppings_keywords)
            elif category == "שתייה":
                phrase = find_phrase_in_text(original_text, drinks_keywords)
            elif category == "רוטב":
                phrase = find_phrase_in_text(original_text, sauces_keywords)
            elif category == "קינוח":
                phrase = find_phrase_in_text(original_text, Desserts_keywords)
            else:
                phrase = None

            new_row["תאור פריט"] = phrase if phrase else f"{qty} {category}"
            new_row["כמות"] = qty
            rows.append(new_row)

    else:
        new_row = base_data.copy()
        new_row["תאור פריט"] = row["תאור פריט"]
        new_row["כמות"] = default_qty
        rows.append(new_row)

df_split = pd.DataFrame(rows)

# %%
df_split
# Out:
#              Date  Year  Month  Day  Day_Name  Is_Weekend      הזמנה   סכום  \
# 0      2022-01-01  2022      1    1         7           1    14321.0   85.9
# 1      2022-01-01  2022      1    1         7           1    14304.0   85.9
# 2      2022-01-01  2022      1    1         7           1    14358.0   89.9
# 3      2022-01-01  2022      1    1         7           1    14323.0   85.9
# 4      2022-01-01  2022      1    1         7           1    14355.0   85.9
# ...           ...   ...    ...  ...       ...         ...        ...    ...
# 239514 2024-12-31  2024     12   31         3           0  7669585.0   19.9
# 239515 2024-12-31  2024     12   31         3           0  7669605.0   19.9
# 239516 2024-12-31  2024     12   31         3           0  7669605.0   19.9
# 239517 2024-12-31  2024     12   31         3           0  7669633.0  384.0
# 239518 2024-12-31  2024     12   31         3           0  7669633.0  384.0
#
#             קטגוריות בתיאור              תאור פריט  כמות
# 0              [מנה עיקרית]         ביאנקה 14'  []     1
# 1              [מנה עיקרית]        טוסקנית  14' []     1
# 2              [מנה עיקרית]        המומלצת  14' []     1
# 3              [מנה עיקרית]  טוסקנית בצק דק 14' []     1
# 4              [מנה עיקרית]  טוסקנית בצק דק 14' []     1
# ...                     ...                    ...   ...
# 239514  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
# 239515  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239516  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
# 239517  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239518  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
#
# [239519 rows x 11 columns]

# %%
def clean_description_keep_numbers(text):
    if pd.isna(text):
        return ""

    text = text.lower()
    # נשאיר מספרים! רק ננקה תווים מיותרים
    text = re.sub(r"[\[\]\"\'\+\-\(\)\.,]", "", text)
    text = re.sub(r"\s{2,}", " ", text)  # רווחים כפולים
    return text.strip()

# %%
df_split["תיאור פריט מנוקה"] = df_split["תאור פריט"].apply(clean_description_keep_numbers)

# %%
df_split = df_split[~df_split["תיאור פריט מנוקה"].str.startswith("בלי")]

# %%
df_split
# Out:
#              Date  Year  Month  Day  Day_Name  Is_Weekend      הזמנה   סכום  \
# 0      2022-01-01  2022      1    1         7           1    14321.0   85.9
# 1      2022-01-01  2022      1    1         7           1    14304.0   85.9
# 2      2022-01-01  2022      1    1         7           1    14358.0   89.9
# 3      2022-01-01  2022      1    1         7           1    14323.0   85.9
# 4      2022-01-01  2022      1    1         7           1    14355.0   85.9
# ...           ...   ...    ...  ...       ...         ...        ...    ...
# 239514 2024-12-31  2024     12   31         3           0  7669585.0   19.9
# 239515 2024-12-31  2024     12   31         3           0  7669605.0   19.9
# 239516 2024-12-31  2024     12   31         3           0  7669605.0   19.9
# 239517 2024-12-31  2024     12   31         3           0  7669633.0  384.0
# 239518 2024-12-31  2024     12   31         3           0  7669633.0  384.0
#
#             קטגוריות בתיאור              תאור פריט  כמות  \
# 0              [מנה עיקרית]         ביאנקה 14'  []     1
# 1              [מנה עיקרית]        טוסקנית  14' []     1
# 2              [מנה עיקרית]        המומלצת  14' []     1
# 3              [מנה עיקרית]  טוסקנית בצק דק 14' []     1
# 4              [מנה עיקרית]  טוסקנית בצק דק 14' []     1
# ...                     ...                    ...   ...
# 239514  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
# 239515  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239516  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
# 239517  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239518  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
#
#              תיאור פריט מנוקה
# 0                   ביאנקה 14
# 1                  טוסקנית 14
# 2                  המומלצת 14
# 3           טוסקנית בצק דק 14
# 4           טוסקנית בצק דק 14
# ...                       ...
# 239514  2 תוספות צמחוניות חבר
# 239515     2 משפחתיות קלאסיות
# 239516  2 תוספות צמחוניות חבר
# 239517     2 משפחתיות קלאסיות
# 239518  2 תוספות צמחוניות חבר
#
# [236961 rows x 12 columns]

# %%
df_split["כמות"].describe()
# Out:
# count    236961.000000
# mean          1.271564
# std           0.761156
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          80.000000
# Name: כמות, dtype: float64

# %%
df_split[df_split["כמות"] >3].sort_values("כמות", ascending=False)
# Out:
#              Date  Year  Month  Day  Day_Name  Is_Weekend      הזמנה    סכום  \
# 175033 2024-07-15  2024      7   15         2           0  7653832.0  5832.0
# 136879 2024-03-28  2024      3   28         5           0  7644193.0     0.0
# 136848 2024-03-28  2024      3   28         5           0  7644193.0  5173.2
# 87841  2023-06-12  2023      6   12         2           0  7616732.0     0.0
# 174906 2024-07-15  2024      7   15         2           0  7653832.0   178.2
# ...           ...   ...    ...  ...       ...         ...        ...     ...
# 157417 2024-05-23  2024      5   23         5           0  7649729.0    11.6
# 1099   2022-01-03  2022      1    3         2           0    14530.0   125.0
# 1100   2022-01-03  2022      1    3         2           0    14590.0   125.0
# 1341   2022-01-04  2022      1    4         3           0    14699.0    10.0
# 1439   2022-01-04  2022      1    4         3           0    14619.0    13.6
#
#        קטגוריות בתיאור           תאור פריט  כמות    תיאור פריט מנוקה
# 175033    [מנה עיקרית]   קלאסית דקה 14' []    80       קלאסית דקה 14
# 136879          [רוטב]           עם אורגנו    54           עם אורגנו
# 136848    [מנה עיקרית]      היוונית 16' []    54          היוונית 16
# 87841     [מנה עיקרית]   קלאסית דקה 14' []    39       קלאסית דקה 14
# 174906         [תוספת]        זיתים ירוקים    36        זיתים ירוקים
# ...                ...                 ...   ...                 ...
# 157417         [תוספת]        זיתים ירוקים     4        זיתים ירוקים
# 1099      [מנה עיקרית]      4 פיצות אישיות     4      4 פיצות אישיות
# 1100      [מנה עיקרית]      4 פיצות אישיות     4      4 פיצות אישיות
# 1341            [רוטב]  רוטב שום פרמזן קטן     4  רוטב שום פרמזן קטן
# 1439           [תוספת]                טונה     4                טונה
#
# [3138 rows x 12 columns]

# %%
# קיבוץ לפי תיאור פריט מנוקה
item_demand = df_split.groupby("תיאור פריט מנוקה")["כמות"].sum().reset_index()

# חישוב אחוזון 10%
threshold = item_demand["כמות"].quantile(0.30)

# שמירה רק על פריטים שנמכרו יותר מהרף
frequent_items = item_demand[item_demand["כמות"] >= threshold]["תיאור פריט מנוקה"]

# סינון הדאטה
df_filtered = df_split[df_split["תיאור פריט מנוקה"].isin(frequent_items)]

# %%
item_demand = df_split.groupby("תיאור פריט מנוקה")["כמות"].sum().reset_index()

# %%
item_demand[item_demand["כמות"] > 50].sort_values("כמות", ascending=False)
# Out:
#              תיאור פריט מנוקה   כמות
# 538                 קלאסית 14  31191
# 190              זיתים ירוקים  19188
# 389                    פטריות  14794
# 552                  קלאסית 8   9828
# 650                      תירס   9753
# ..                        ...    ...
# 177          הצמחונית איטסיין     52
# 566                  קלסית 14     52
# 348        עוגת ריקוטה שוקולד     51
# 369               פאפא מיקס 8     51
# 528  צמחונית ללא גלוטן פסח 14     51
#
# [257 rows x 2 columns]

# %%
high_demand_items = item_demand[item_demand["כמות"] >= 50]["תיאור פריט מנוקה"]

# %%
df_split = df_split[df_split["תיאור פריט מנוקה"].isin(high_demand_items)]

# %%
# !pip install holidays
# Out:
# Requirement already satisfied: holidays in /usr/local/lib/python3.11/dist-packages (0.70)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from holidays) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->holidays) (1.17.0)

# %%
import holidays

# נניח שעמודת התאריכים שלך היא בשם "Date"
df_split["Date"] = pd.to_datetime(df_split["Date"])  # ודא שהיא datetime

# הגדרת חגים אמריקאיים (או מדינה אחרת לפי הצורך)
us_holidays = holidays.US()

# הוספת עמודה - האם התאריך הוא חג נוצרי
df_split["is_christian_holiday"] = df_split["Date"].dt.date.apply(lambda x: x in us_holidays)
# Out:
# <ipython-input-42-b2b255d1a994>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_split["Date"] = pd.to_datetime(df_split["Date"])  # ודא שהיא datetime
# <ipython-input-42-b2b255d1a994>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_split["is_christian_holiday"] = df_split["Date"].dt.date.apply(lambda x: x in us_holidays)

# %%
df_split["christian_holiday_name"] = df_split["Date"].dt.date.apply(lambda x: us_holidays.get(x) if x in us_holidays else None)
# Out:
# <ipython-input-43-817ef556b752>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_split["christian_holiday_name"] = df_split["Date"].dt.date.apply(lambda x: us_holidays.get(x) if x in us_holidays else None)

# %%
df_split.tail(20)
# Out:
#              Date  Year  Month  Day  Day_Name  Is_Weekend      הזמנה   סכום  \
# 239499 2024-12-31  2024     12   31         3           0  7669569.0    0.0
# 239500 2024-12-31  2024     12   31         3           0  7669602.0    0.0
# 239501 2024-12-31  2024     12   31         3           0  7669605.0    0.0
# 239502 2024-12-31  2024     12   31         3           0  7669616.0    0.0
# 239503 2024-12-31  2024     12   31         3           0  7669551.0    0.0
# 239504 2024-12-31  2024     12   31         3           0  7669633.0   80.0
# 239505 2024-12-31  2024     12   31         3           0  7669482.0    0.0
# 239506 2024-12-31  2024     12   31         3           0  7669547.0    0.0
# 239507 2024-12-31  2024     12   31         3           0  7669550.0    0.0
# 239508 2024-12-31  2024     12   31         3           0  7669561.0    0.0
# 239509 2024-12-31  2024     12   31         3           0  7669562.0    0.0
# 239510 2024-12-31  2024     12   31         3           0  7669633.0  125.0
# 239511 2024-12-31  2024     12   31         3           0  7669582.0    0.0
# 239512 2024-12-31  2024     12   31         3           0  7669582.0    0.0
# 239513 2024-12-31  2024     12   31         3           0  7669585.0   19.9
# 239514 2024-12-31  2024     12   31         3           0  7669585.0   19.9
# 239515 2024-12-31  2024     12   31         3           0  7669605.0   19.9
# 239516 2024-12-31  2024     12   31         3           0  7669605.0   19.9
# 239517 2024-12-31  2024     12   31         3           0  7669633.0  384.0
# 239518 2024-12-31  2024     12   31         3           0  7669633.0  384.0
#
#             קטגוריות בתיאור              תאור פריט  כמות  \
# 239499               [רוטב]                 רוטבים     1
# 239500               [רוטב]                 רוטבים     2
# 239501               [רוטב]                 רוטבים     1
# 239502               [רוטב]                 רוטבים     1
# 239503                [אחר]         שובר 100 שח DV     1
# 239504                [אחר]         שובר 100 שח DV     1
# 239505                [אחר]          שובר 50 שח DV     1
# 239506                [אחר]          שובר 50 שח DV     1
# 239507                [אחר]          שובר 50 שח DV     1
# 239508                [אחר]          שובר 50 שח DV     1
# 239509                [אחר]          שובר 50 שח DV     1
# 239510                [אחר]          שובר 50 שח DV     5
# 239511  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239512  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
# 239513  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239514  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
# 239515  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239516  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
# 239517  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239518  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
#
#              תיאור פריט מנוקה  is_christian_holiday christian_holiday_name
# 239499                 רוטבים                 False                   None
# 239500                 רוטבים                 False                   None
# 239501                 רוטבים                 False                   None
# 239502                 רוטבים                 False                   None
# 239503         שובר 100 שח dv                 False                   None
# 239504         שובר 100 שח dv                 False                   None
# 239505          שובר 50 שח dv                 False                   None
# 239506          שובר 50 שח dv                 False                   None
# 239507          שובר 50 שח dv                 False                   None
# 239508          שובר 50 שח dv                 False                   None
# 239509          שובר 50 שח dv                 False                   None
# 239510          שובר 50 שח dv                 False                   None
# 239511     2 משפחתיות קלאסיות                 False                   None
# 239512  2 תוספות צמחוניות חבר                 False                   None
# 239513     2 משפחתיות קלאסיות                 False                   None
# 239514  2 תוספות צמחוניות חבר                 False                   None
# 239515     2 משפחתיות קלאסיות                 False                   None
# 239516  2 תוספות צמחוניות חבר                 False                   None
# 239517     2 משפחתיות קלאסיות                 False                   None
# 239518  2 תוספות צמחוניות חבר                 False                   None

# %%
# !pip install convertdate
# Out:
# Requirement already satisfied: convertdate in /usr/local/lib/python3.11/dist-packages (2.4.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.11/dist-packages (from convertdate) (0.5.12)

# %%
from convertdate import hebrew

# הגדרת חגים יהודיים לפי הלוח העברי
jewish_holidays = {
    "ראש השנה": [(1, 1), (2, 1)],
    "יום כיפור": [(10, 1)],
    "סוכות": [(15, 1), (16, 1)],
    "שמיני עצרת": [(22, 1)],
    "חנוכה": [(25, 9), (26, 9), (27, 9), (28, 9), (29, 9), (30, 9), (1, 10), (2, 10)],
    "ט\"ו בשבט": [(15, 11)],
    "פורים": [(14, 12)],
    "פסח": [(15, 1), (16, 1), (21, 1), (22, 1)],
    "יום העצמאות": [(5, 2)],
    "שבועות": [(6, 3)],}

# פונקציה שמחזירה גם True/False וגם את שם החג (אם יש)
def get_jewish_holiday_info(gdate):
    h_year, h_month, h_day = hebrew.from_gregorian(gdate.year, gdate.month, gdate.day)
    for holiday_name, days in jewish_holidays.items():
        if (h_day, h_month) in days:
            return True, holiday_name
    return False, None

# החלת הפונקציה על העמודה
df_split["is_jewish_holiday"], df_split["jewish_holiday_name"] = zip(*df_split["Date"].dt.date.apply(get_jewish_holiday_info))
# Out:
# <ipython-input-46-81104877b0ac>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_split["is_jewish_holiday"], df_split["jewish_holiday_name"] = zip(*df_split["Date"].dt.date.apply(get_jewish_holiday_info))
# <ipython-input-46-81104877b0ac>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_split["is_jewish_holiday"], df_split["jewish_holiday_name"] = zip(*df_split["Date"].dt.date.apply(get_jewish_holiday_info))

# %%
from datetime import timedelta

# שלב 1: בניית רשימה של תאריכי חגים בלוח הלועזי (Gregorian)
all_holiday_dates = []

for year in df_split["Date"].dt.year.unique():
    for holiday_days in jewish_holidays.values():
        for day, month in holiday_days:
            try:
                g_date = date(*hebrew.to_gregorian(year, month, day))
                all_holiday_dates.append(g_date)
            except:
                pass  # טיפולי בתאריכים שלא קיימים בשנה מסוימת (למשל, אדר ב')

# שלב 2: יצירת טווח של ±2 ימים סביב כל חג
near_holiday_dates = set()
for d in all_holiday_dates:
    for offset in range(-2, 3):  # יומיים לפני, אחרי, כולל החג
        near_holiday_dates.add(d + timedelta(days=offset))

# שלב 3: הוספת עמודת is_near_jewish_holiday
df_split["is_near_jewish_holiday"] = df_split["Date"].dt.date.apply(lambda x: x in near_holiday_dates)
# Out:
# <ipython-input-47-d7fba18d3ae3>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_split["is_near_jewish_holiday"] = df_split["Date"].dt.date.apply(lambda x: x in near_holiday_dates)

# %%
# ודא שהתאריך בפורמט datetime
df_split["Date"] = pd.to_datetime(df_split["Date"])

# יצירת עמודה חדשה: האם התאריך הוא 31.12
df_split["is_day_before_new_year"] = (df_split["Date"].dt.month == 12) & (df_split["Date"].dt.day == 31)
# Out:
# <ipython-input-48-f82f6e4e4a56>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_split["Date"] = pd.to_datetime(df_split["Date"])
# <ipython-input-48-f82f6e4e4a56>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_split["is_day_before_new_year"] = (df_split["Date"].dt.month == 12) & (df_split["Date"].dt.day == 31)

# %%
df_split = df_split[~df_split["תאור פריט"].str.contains("שובר", na=False)]

# %%
df_split
# Out:
#              Date  Year  Month  Day  Day_Name  Is_Weekend      הזמנה   סכום  \
# 0      2022-01-01  2022      1    1         7           1    14321.0   85.9
# 1      2022-01-01  2022      1    1         7           1    14304.0   85.9
# 2      2022-01-01  2022      1    1         7           1    14358.0   89.9
# 3      2022-01-01  2022      1    1         7           1    14323.0   85.9
# 4      2022-01-01  2022      1    1         7           1    14355.0   85.9
# ...           ...   ...    ...  ...       ...         ...        ...    ...
# 239514 2024-12-31  2024     12   31         3           0  7669585.0   19.9
# 239515 2024-12-31  2024     12   31         3           0  7669605.0   19.9
# 239516 2024-12-31  2024     12   31         3           0  7669605.0   19.9
# 239517 2024-12-31  2024     12   31         3           0  7669633.0  384.0
# 239518 2024-12-31  2024     12   31         3           0  7669633.0  384.0
#
#             קטגוריות בתיאור              תאור פריט  כמות  \
# 0              [מנה עיקרית]         ביאנקה 14'  []     1
# 1              [מנה עיקרית]        טוסקנית  14' []     1
# 2              [מנה עיקרית]        המומלצת  14' []     1
# 3              [מנה עיקרית]  טוסקנית בצק דק 14' []     1
# 4              [מנה עיקרית]  טוסקנית בצק דק 14' []     1
# ...                     ...                    ...   ...
# 239514  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
# 239515  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239516  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
# 239517  [תוספת, מנה עיקרית]     2 משפחתיות קלאסיות     2
# 239518  [תוספת, מנה עיקרית]  2 תוספות צמחוניות חבר     2
#
#              תיאור פריט מנוקה  is_christian_holiday christian_holiday_name  \
# 0                   ביאנקה 14                  True         New Year's Day
# 1                  טוסקנית 14                  True         New Year's Day
# 2                  המומלצת 14                  True         New Year's Day
# 3           טוסקנית בצק דק 14                  True         New Year's Day
# 4           טוסקנית בצק דק 14                  True         New Year's Day
# ...                       ...                   ...                    ...
# 239514  2 תוספות צמחוניות חבר                 False                   None
# 239515     2 משפחתיות קלאסיות                 False                   None
# 239516  2 תוספות צמחוניות חבר                 False                   None
# 239517     2 משפחתיות קלאסיות                 False                   None
# 239518  2 תוספות צמחוניות חבר                 False                   None
#
#         is_jewish_holiday jewish_holiday_name  is_near_jewish_holiday  \
# 0                   False                None                   False
# 1                   False                None                   False
# 2                   False                None                   False
# 3                   False                None                   False
# 4                   False                None                   False
# ...                   ...                 ...                     ...
# 239514               True               חנוכה                   False
# 239515               True               חנוכה                   False
# 239516               True               חנוכה                   False
# 239517               True               חנוכה                   False
# 239518               True               חנוכה                   False
#
#         is_day_before_new_year
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 239514                    True
# 239515                    True
# 239516                    True
# 239517                    True
# 239518                    True
#
# [231403 rows x 18 columns]

# %%
df_split = df_split.drop(columns=["תאור פריט"])

# %%
# קידוד ערכי ההזמנה
df_split["order"] = pd.factorize(df_split["הזמנה"])[0]

# הסרת העמודה המקורית
df_split = df_split.drop(columns=["הזמנה"])

# %%
df_split["clean_desc_encoded"] = pd.factorize(df_split["תיאור פריט מנוקה"])[0]

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# ודא שכל תא הוא רשימה
df_split["קטגוריות בתיאור"] = df_split["קטגוריות בתיאור"].apply(lambda x: x if isinstance(x, list) else [x])

# הפעלת one-hot encoding
mlb = MultiLabelBinarizer()
one_hot = pd.DataFrame(mlb.fit_transform(df_split["קטגוריות בתיאור"]),
                       columns=mlb.classes_,
                       index=df_split.index)

# חיבור לדאטה המקורי
df_split = pd.concat([df_split, one_hot], axis=1)

# %%
# הפעלת factorize ושמירה של שני הערכים המוחזרים
codes, uniques = pd.factorize(df_split["תיאור פריט מנוקה"])

# יצירת עמודת הקידוד
df_split["clean_desc_encoded"] = codes

# יצירת מילון מיפוי
desc_mapping = {val: i for i, val in enumerate(uniques)}

# %%
pd.Series(desc_mapping).to_csv("desc_encoding_map.csv", header=["code"])

# %%
df_split = df_split.drop(columns=["קטגוריות בתיאור", "תיאור פריט מנוקה"])

# %%
df_split['WeekOfYear'] = df_split['Date'].dt.isocalendar().week

# %%
df_split['Season'] = (df_split['Month'] % 12 // 3 + 1)

# %%
df_split['is_start_of_month'] = (df_split['Day'] <= 3).astype(int)

# %%
df_split['is_end_of_month'] = (df_split['Day'] >= 28).astype(int)

# %%
import numpy as np
df_split['Day_Name_sin'] = np.sin(2 * np.pi * df_split['Day_Name'] / 7)
df_split['Day_Name_cos'] = np.cos(2 * np.pi * df_split['Day_Name'] / 7)

# %%
df_split['Month_sin'] = np.sin(2 * np.pi * df_split['Month'] / 12)
df_split['Month_cos'] = np.cos(2 * np.pi * df_split['Month'] / 12)

# %%
df_split.to_csv("cleaned_data.csv", index=False)
