# %% [markdown]
# ##Prophet

# %%
#!pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.11/dist-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.11/dist-packages (from prophet) (0.70)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.11/dist-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from holidays<1,>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Load dataset
df = pd.read_csv('/content/drive/MyDrive/cleaned_data.csv')
df['Date'] = pd.to_datetime(df['Date'])

# Load dish name mapping
mapping_df = pd.read_csv('/content/drive/MyDrive/desc_encoding_map.csv')
mapping_df = mapping_df.rename(columns={'Unnamed: 0': 'description', 'code': 'dish'})

# %%
# Top 10 most sold dishes
top_dishes = df.groupby('clean_desc_encoded')['כמות'].sum().sort_values(ascending=False).head(10).index.tolist()

# Pivot for time series format
daily = df[df['clean_desc_encoded'].isin(top_dishes)].groupby(['Date', 'clean_desc_encoded'])['כמות'].sum().reset_index()
pivot_df = daily.pivot(index='Date', columns='clean_desc_encoded', values='כמות').fillna(0)

# Prophet loop
prophet_results = []

for dish in tqdm(top_dishes):
    df_prophet = pivot_df[[dish]].reset_index()
    df_prophet.columns = ['ds', 'y']
    df_prophet = df_prophet.dropna()
    df_prophet['y'] = df_prophet['y'].astype(float)

    split_idx = int(len(df_prophet) * 0.8)
    train = df_prophet.iloc[:split_idx]
    test = df_prophet.iloc[split_idx:]

    try:
        model = Prophet(weekly_seasonality=True, yearly_seasonality=True, daily_seasonality=False)
        model.fit(train)

        future = model.make_future_dataframe(periods=len(test))
        forecast = model.predict(future)

        common_dates = test['ds'][test['ds'].isin(forecast['ds'])]
        pred = forecast.set_index('ds').loc[common_dates, 'yhat'].values
        test_y = test.set_index('ds').loc[common_dates, 'y'].values

        # Metrics
        mae = mean_absolute_error(test_y, pred)
        rmse = np.sqrt(mean_squared_error(test_y, pred))
        r2 = r2_score(test_y, pred)
        n = len(test_y)
        p = 0  # Prophet doesn’t use explicit regressors here
        adj_r2 = 1 - (1 - r2) * ((n - 1) / (n - p - 1))

        mask = test_y > 0
        mape = np.mean(np.abs((test_y[mask] - pred[mask]) / test_y[mask])) * 100 if mask.sum() > 0 else np.nan

        prophet_results.append({
            'dish': dish,
            'MAE': np.ceil(mae),
            'RMSE': np.ceil(rmse),
            'MAPE (%)': np.ceil(mape),
            'R2': r2,
            'Adjusted R2': adj_r2
        })

    except Exception as e:
        print(f"❌ Error en dish {dish}: {e}")
        prophet_results.append({
            'dish': dish,
            'MAE': np.nan,
            'RMSE': np.nan,
            'MAPE (%)': np.nan,
            'R2': np.nan,
            'Adjusted R2': np.nan
        })

# Final table with dish names
results_df = pd.DataFrame(prophet_results)
results_df = results_df.merge(mapping_df, on='dish', how='left')
results_df = results_df[['dish', 'description', 'MAE', 'RMSE', 'MAPE (%)', 'R2', 'Adjusted R2']].sort_values('RMSE').reset_index(drop=True)
results_df
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/w0i3f4ke.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/wumc2pd1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95366', 'data', 'file=/tmp/tmp5jun0bbp/w0i3f4ke.json', 'init=/tmp/tmp5jun0bbp/wumc2pd1.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modelyhg5tm3x/prophet_model-20250417073649.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  10%|█         | 1/10 [00:00<00:04,  2.24it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/s0j14t_a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/d8s7h4r8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8890', 'data', 'file=/tmp/tmp5jun0bbp/s0j14t_a.json', 'init=/tmp/tmp5jun0bbp/d8s7h4r8.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modeldwierehn/prophet_model-20250417073649.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  20%|██        | 2/10 [00:01<00:05,  1.56it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/jf4sy1hu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/qvyq2w1w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46980', 'data', 'file=/tmp/tmp5jun0bbp/jf4sy1hu.json', 'init=/tmp/tmp5jun0bbp/qvyq2w1w.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modellrmkm084/prophet_model-20250417073650.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  30%|███       | 3/10 [00:02<00:05,  1.25it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/0hkjnuct.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/fcqp6gjy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65541', 'data', 'file=/tmp/tmp5jun0bbp/0hkjnuct.json', 'init=/tmp/tmp5jun0bbp/fcqp6gjy.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modelbrunkpxz/prophet_model-20250417073651.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  40%|████      | 4/10 [00:02<00:03,  1.73it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/kle0lmqz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/xs6nbtuw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43781', 'data', 'file=/tmp/tmp5jun0bbp/kle0lmqz.json', 'init=/tmp/tmp5jun0bbp/xs6nbtuw.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modeluuicjgwy/prophet_model-20250417073651.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  50%|█████     | 5/10 [00:02<00:02,  2.13it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/e29mw1ym.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/67zkchj7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70667', 'data', 'file=/tmp/tmp5jun0bbp/e29mw1ym.json', 'init=/tmp/tmp5jun0bbp/67zkchj7.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modelo3espi3s/prophet_model-20250417073651.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  60%|██████    | 6/10 [00:02<00:01,  2.48it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/gfu8xmeq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/7t30r86f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80246', 'data', 'file=/tmp/tmp5jun0bbp/gfu8xmeq.json', 'init=/tmp/tmp5jun0bbp/7t30r86f.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_model80597gu2/prophet_model-20250417073651.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  70%|███████   | 7/10 [00:03<00:01,  2.85it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/xxcafxd9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/l1skeiaf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11930', 'data', 'file=/tmp/tmp5jun0bbp/xxcafxd9.json', 'init=/tmp/tmp5jun0bbp/l1skeiaf.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_model8ki1fd5j/prophet_model-20250417073652.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  80%|████████  | 8/10 [00:03<00:00,  3.12it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/i42wr5rx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/einbe7ip.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=466', 'data', 'file=/tmp/tmp5jun0bbp/i42wr5rx.json', 'init=/tmp/tmp5jun0bbp/einbe7ip.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modeldcex7rxk/prophet_model-20250417073652.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#  90%|█████████ | 9/10 [00:03<00:00,  3.37it/s]DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/mdu689kn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/c3599mjr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85836', 'data', 'file=/tmp/tmp5jun0bbp/mdu689kn.json', 'init=/tmp/tmp5jun0bbp/c3599mjr.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modelf2aoubr_/prophet_model-20250417073652.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:36:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:36:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 100%|██████████| 10/10 [00:04<00:00,  2.43it/s]
#    dish       description   MAE  RMSE  MAPE (%)        R2  Adjusted R2
# 0    64     קלאסית דקה 14   5.0   7.0      62.0  0.068671     0.068671
# 1    56  2 פיצות משפחתיות   6.0   8.0      61.0  0.128678     0.128678
# 2    53        פיצה אישית   6.0   8.0      83.0 -0.616704    -0.616704
# 3    43          בצל סגול   9.0  11.0      96.0 -0.303583    -0.303583
# 4    34            פטריות  11.0  14.0      81.0 -0.108381    -0.108381
# 5    63          קלאסית 8  14.0  16.0     117.0 -3.330232    -3.330232
# 6    35              תירס  14.0  18.0     128.0 -3.130261    -3.130261
# 7    36      זיתים ירוקים  16.0  20.0      90.0 -0.579387    -0.579387
# 8    62         קלאסית 14  20.0  26.0      53.0  0.028774     0.028774
# 9   234         שקית לקוח  66.0  81.0     313.0 -8.784594    -8.784594

# %%
# 🔍 Plato con menor RMSE
best_dish = results_df.iloc[0]['dish']
best_dish_name = results_df.iloc[0]['description'][::-1]  # invertimos el texto hebreo para mostrarlo bien

# 📦 Preparar datos para el mejor plato
df_prophet = pivot_df[[best_dish]].reset_index()
df_prophet.columns = ['ds', 'y']
df_prophet = df_prophet.dropna()
df_prophet['y'] = df_prophet['y'].astype(float)

# 🧪 Train/Test split
split_idx = int(len(df_prophet) * 0.8)
train = df_prophet.iloc[:split_idx]
test = df_prophet.iloc[split_idx:]

# 🔮 Entrenar y predecir
model = Prophet(weekly_seasonality=True, yearly_seasonality=True, daily_seasonality=False)
model.fit(train)
future = model.make_future_dataframe(periods=len(test))
forecast = model.predict(future)

# 📊 Forecast vs Real
common_dates = test['ds'][test['ds'].isin(forecast['ds'])]
pred = forecast.set_index('ds').loc[common_dates, 'yhat']
real = test.set_index('ds').loc[common_dates, 'y']

# 📈 Plot
plt.figure(figsize=(12, 5))
plt.plot(real.index, real, label='Real', linewidth=2)
plt.plot(pred.index, pred, label='Forecast (Prophet)', linewidth=2)
plt.title(f'Forecast vs Real - Dish {best_dish_name} (Lowest RMSE value)')
plt.xlabel('Date')
plt.ylabel('Quantity sold')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/qjj4z_8_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/x889scbi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84362', 'data', 'file=/tmp/tmp5jun0bbp/qjj4z_8_.json', 'init=/tmp/tmp5jun0bbp/x889scbi.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modeltmijmbx7/prophet_model-20250417073939.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:39:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:39:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Prepare data for a specific dish (example: dish 64)
df_prophet = pivot_df[[64]].reset_index()
df_prophet.columns = ['ds', 'y']  # Prophet requires 'ds' for dates and 'y' for values
df_prophet = df_prophet.dropna()

# Fit the Prophet model using ALL available data
model = Prophet(weekly_seasonality=True, yearly_seasonality=True, daily_seasonality=False)
model.fit(df_prophet)

# Extend the timeline to include future dates
future = model.make_future_dataframe(periods=250)  # adjust the period as needed
forecast = model.predict(future)

# Pick a future date to forecast
target_date = '2025-08-10'

# Retrieve and round the forecasted value
pred_value = forecast.loc[forecast['ds'] == target_date, 'yhat']

if not pred_value.empty:
    rounded_value = int(np.ceil(pred_value.values[0]))
    print(f"📆 Forecast for {target_date}: {rounded_value} units sold")
else:
    print(f"⚠️ No prediction found for the date {target_date}")
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/1iw6qxc5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5jun0bbp/7a35amb9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27535', 'data', 'file=/tmp/tmp5jun0bbp/1iw6qxc5.json', 'init=/tmp/tmp5jun0bbp/7a35amb9.json', 'output', 'file=/tmp/tmp5jun0bbp/prophet_modelenj7s0x4/prophet_model-20250417073004.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:30:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:30:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 📆 Forecast for 2025-08-10: 11 units sold
